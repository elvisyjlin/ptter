# %% [markdown]
# # PTTer
#
# A crawler for www.ptt.cc (批踢踢實業坊)

# %%
import requests
import json
from bs4 import BeautifulSoup as bs

# %%
IP_KEYWORD = '來自: '
URL_KEYWORD = '文章網址: '

def get_page(board, id, save_path=None):
    url = 'https://www.ptt.cc/bbs/{}/{}.html'.format(board, id)
    res = requests.get(url)
    text = res.text
    if save_path is not None:
        with open(save_path, 'w', encoding='utf-8') as f:
            f.write(text)
    soup = bs(text, 'html.parser')
    return soup

def parse_page(page, keep_main_content=False, save_path=None):
    post = {}
    post['url'] = page.find(lambda tag: tag.name == 'span' and URL_KEYWORD in tag.text).find('a').text
    _, post['article_id'] = post['url'].rsplit('.', 1)[0].rsplit('/', 2)[1:]
    for metaline_div in page.find_all('div', {'class': 'article-metaline'}):
        if metaline_div.find('span', {'class': 'article-meta-tag'}).text == '作者':
            post['author'] = metaline_div.find('span', {'class': 'article-meta-value'}).text
        if metaline_div.find('span', {'class': 'article-meta-tag'}).text == '看板':
            post['board'] = metaline_div.find('span', {'class': 'article-meta-value'}).text
        if metaline_div.find('span', {'class': 'article-meta-tag'}).text == '標題':
            post['article_title'] = metaline_div.find('span', {'class': 'article-meta-value'}).text
        if metaline_div.find('span', {'class': 'article-meta-tag'}).text == '時間':
            post['datetime'] = metaline_div.find('span', {'class': 'article-meta-value'}).text
    post['ip'] = page.find(lambda tag: tag.name == 'span' and IP_KEYWORD in tag.text).text.split('來自: ')[1].strip()
    post['main_content'] = page.find('div', {'id': 'main-container'}).text.split('\n')
    if not keep_main_content:
        post['content'] = []
        for line in post['main_content'][2:]:
            if IP_KEYWORD in line:
                break
            post['content'].append(line)
        post['pushes'] = []
        for push_div in page.find_all('div', {'class': 'push'}):
            push = {
                'push_tag': push_div.find('span', {'class': 'push-tag'}).text.strip(), 
                'push_userid': push_div.find('span', {'class': 'push-userid'}).text.strip(), 
                'push_content': push_div.find('span', {'class': 'push-content'}).text[1:].strip(), 
                'push_ipdatetime': push_div.find('span', {'class': 'push-ipdatetime'}).text.strip()
            }
            post['pushes'].append(push)
        del post['main_content']
    if save_path is not None:
        with open(save_path, 'w', encoding='utf-8') as f:
            f.write(json.dumps(post))
    return post

# %%
board = 'Beauty'
id = 'M.1527694127.A.D6E'

page = get_page(board, id, save_path=None)
post = parse_page(page, keep_main_content=False, save_path=None)

# %%
page
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8">
# <meta content="width=device-width, initial-scale=1" name="viewport">
# <title>[正妹] 新竹女中 回眸 - 看板 Beauty - 批踢踢實業坊</title>
# <meta content="all" name="robots">
# <meta content="Ptt BBS 批踢踢" name="keywords">
# <meta content="新竹女中 學生自己創作的畢業歌《回眸》
# https://youtu.be/2_zxqFmE9hE
# 其中MV裡面的高中妹妹，顏值顏質看起來還不錯
# 就稍微找了一下
# 1號 沒繡學號的這位 是我最喜歡的類型
# " name="description">
# <meta content="Ptt 批踢踢實業坊" property="og:site_name">
# <meta content="[正妹] 新竹女中 回眸" property="og:title">
# <meta content="新竹女中 學生自己創作的畢業歌《回眸》
# https://youtu.be/2_zxqFmE9hE
# 其中MV裡面的高中妹妹，顏值顏質看起來還不錯
# 就稍微找了一下
# 1號 沒繡學號的這位 是我最喜歡的類型
# " property="og:description">
# <link href="https://www.ptt.cc/bbs/Beauty/M.1527694127.A.D6E.html" rel="canonical">
# <link href="//images.ptt.cc/bbs/v2.25/bbs-common.css" rel="stylesheet" type="text/css">
# <link href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen" rel="stylesheet" type="text/css">
# <link href="//images.ptt.cc/bbs/v2.25/bbs-custom.css" rel="stylesheet" type="text/css">
# <link href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen" rel="stylesheet" type="text/css">
# <link href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print" rel="stylesheet" type="text/css">
# </link></link></link></link></link></link></meta></meta></meta></meta></meta></meta></meta></meta></head>
# <body>
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
# var js, fjs = d.getElementsByTagName(s)[0];
# if (d.getElementById(id)) return;
# js = d.createElement(s); js.id = id;
# js.src = "//connect.facebook.net/en_US/all.js#xfbml=1";
# fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/Beauty/index.html"><span class="board-label">看板 </span>Beauty</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="navigation-container">
# <div class="bbs-content" id="navigation">
# <a class="board" href="/bbs/Beauty/index.html">返回看板</a>
# <div class="bar"></div>
# <div class="share">
# <span>分享</span>
# <div class="fb-like" data-href="http://www.ptt.cc/bbs/Beauty/M.1527694127.A.D6E.html" data-layout="button_count" data-send="false" data-show-faces="false" data-width="90"></div>
# <div class="g-plusone" data-size="medium"></div>
# <script type="text/javascript">
# window.___gcfg = {lang: 'zh-TW'};
# (function() {
# var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
# po.src = 'https://apis.google.com/js/plusone.js';
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
# })();
# </script>
# </div>
# </div>
# </div>
# <div id="main-container">
# <div class="bbs-screen bbs-content" id="main-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">james7923 (詹姆士Q)</span></div><div class="article-metaline-right"><span class="article-meta-tag">看板</span><span class="article-meta-value">Beauty</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">[正妹] 新竹女中 回眸</span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Wed May 30 23:28:43 2018</span></div>
# 新竹女中 學生自己創作的畢業歌《回眸》
# <a href="https://youtu.be/2_zxqFmE9hE" rel="nofollow" target="_blank">https://youtu.be/2_zxqFmE9hE</a>
# <div class="richcontent"><div class="resize-container"><div class="resize-content"><iframe allowfullscreen="" class="youtube-player" frameborder="0" src="//www.youtube.com/embed/2_zxqFmE9hE" type="text/html"></iframe></div></div></div>
# 其中MV裡面的高中妹妹，顏值顏質看起來還不錯
#
# 就稍微找了一下
#
# 1號 沒繡學號的這位 是我最喜歡的類型
# [左一]
# <a href="https://i.imgur.com/SbRLjHJ.jpg" rel="nofollow" target="_blank">https://i.imgur.com/SbRLjHJ.jpg</a>
# <div class="richcontent"><blockquote class="imgur-embed-pub" data-id="SbRLjHJ" lang="en"><a href="//imgur.com/SbRLjHJ"></a></blockquote><script async="" charset="utf-8" src="//s.imgur.com/min/embed.js"></script></div>[左一]
# <a href="https://i.imgur.com/xeT3dpg.jpg" rel="nofollow" target="_blank">https://i.imgur.com/xeT3dpg.jpg</a>
# <div class="richcontent"><blockquote class="imgur-embed-pub" data-id="xeT3dpg" lang="en"><a href="//imgur.com/xeT3dpg"></a></blockquote><script async="" charset="utf-8" src="//s.imgur.com/min/embed.js"></script></div>[右邊]
# <a href="https://i.imgur.com/tHlCNQ3.jpg" rel="nofollow" target="_blank">https://i.imgur.com/tHlCNQ3.jpg</a>
# <div class="richcontent"><blockquote class="imgur-embed-pub" data-id="tHlCNQ3" lang="en"><a href="//imgur.com/tHlCNQ3"></a></blockquote><script async="" charset="utf-8" src="//s.imgur.com/min/embed.js"></script></div><a href="https://i.imgur.com/bExaTkO.jpg" rel="nofollow" target="_blank">https://i.imgur.com/bExaTkO.jpg</a>
# <div class="richcontent"><blockquote class="imgur-embed-pub" data-id="bExaTkO" lang="en"><a href="//imgur.com/bExaTkO"></a></blockquote><script async="" charset="utf-8" src="//s.imgur.com/min/embed.js"></script></div><a href="https://i.imgur.com/zXtIa0C.jpg" rel="nofollow" target="_blank">https://i.imgur.com/zXtIa0C.jpg</a>
# <div class="richcontent"><blockquote class="imgur-embed-pub" data-id="zXtIa0C" lang="en"><a href="//imgur.com/zXtIa0C"></a></blockquote><script async="" charset="utf-8" src="//s.imgur.com/min/embed.js"></script></div><a href="https://i.imgur.com/SsISpLn.jpg" rel="nofollow" target="_blank">https://i.imgur.com/SsISpLn.jpg</a>
# <div class="richcontent"><blockquote class="imgur-embed-pub" data-id="SsISpLn" lang="en"><a href="//imgur.com/SsISpLn"></a></blockquote><script async="" charset="utf-8" src="//s.imgur.com/min/embed.js"></script></div><a href="https://i.imgur.com/DlNBX25.jpg" rel="nofollow" target="_blank">https://i.imgur.com/DlNBX25.jpg</a>
# <div class="richcontent"><blockquote class="imgur-embed-pub" data-id="DlNBX25" lang="en"><a href="//imgur.com/DlNBX25"></a></blockquote><script async="" charset="utf-8" src="//s.imgur.com/min/embed.js"></script></div><a href="https://i.imgur.com/QqTe7fp.jpg" rel="nofollow" target="_blank">https://i.imgur.com/QqTe7fp.jpg</a>
# <div class="richcontent"><blockquote class="imgur-embed-pub" data-id="QqTe7fp" lang="en"><a href="//imgur.com/QqTe7fp"></a></blockquote><script async="" charset="utf-8" src="//s.imgur.com/min/embed.js"></script></div><a href="https://i.imgur.com
08
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Bilison</span><span class="f3 push-content">: 堅持才有價值</span><span class="push-ipdatetime"> 05/31 12:42
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">niji5143</span><span class="f3 push-content">: 我想說的意思是，明明還有本錢，沒化妝可能也很好看甚至</span><span class="push-ipdatetime"> 05/31 13:29
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">niji5143</span><span class="f3 push-content">: 更好看，但化了一個不明所以的妝</span><span class="push-ipdatetime"> 05/31 13:29
# </span></div><div class="push"><span class="f1 hl push-tag">噓 </span><span class="f3 hl push-userid">fallensam</span><span class="f3 push-content">: 短髮那位呢</span><span class="push-ipdatetime"> 05/31 13:43
# </span></div></div>
# <div data-longpollurl="/v1/longpoll?id=4cd5ded717199186a399d7c51443569a95f94a9e" data-offset="8062" data-pollurl="/poll/Beauty/M.1527694127.A.D6E.html?cacheKey=2100-621613539&amp;offset=8062&amp;offset-sig=6b7fc2736d993796cd3a034a50be1035754e63bf" id="article-polling"></div>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
# </body>
# </html>

# %%
post
# Out:
# {'article_id': 'M.1527694127.A.D6E',
#  'article_title': '[正妹] 新竹女中 回眸',
#  'author': 'james7923 (詹姆士Q)',
#  'content': ['新竹女中 學生自己創作的畢業歌《回眸》',
#   'https://youtu.be/2_zxqFmE9hE',
#   '',
#   '其中MV裡面的高中妹妹，顏值顏質看起來還不錯',
#   '',
#   '就稍微找了一下',
#   '',
#   '1號 沒繡學號的這位 是我最喜歡的類型',
#   '[左一]',
#   'https://i.imgur.com/SbRLjHJ.jpg',
#   '[左一]',
#   'https://i.imgur.com/xeT3dpg.jpg',
#   '[右邊]',
#   'https://i.imgur.com/tHlCNQ3.jpg',
#   'https://i.imgur.com/bExaTkO.jpg',
#   'https://i.imgur.com/zXtIa0C.jpg',
#   'https://i.imgur.com/SsISpLn.jpg',
#   'https://i.imgur.com/DlNBX25.jpg',
#   'https://i.imgur.com/QqTe7fp.jpg',
#   'https://i.imgur.com/xOrt8eT.jpg',
#   'https://i.imgur.com/xyylS5l.jpg',
#   'https://i.imgur.com/s2uSQNL.jpg',
#   '',
#   '2號',
#   'https://i.imgur.com/TgocRlr.jpg',
#   'https://i.imgur.com/f5kqQYh.jpg',
#   'https://i.imgur.com/AJoNV29.jpg',
#   'https://i.imgur.com/pH7LBRv.jpg',
#   'https://i.imgur.com/T2cAlBt.jpg',
#   'https://i.imgur.com/cGbfstR.jpg',
#   'https://i.imgur.com/m024ZnR.jpg',
#   'https://i.imgur.com/nlh26M1.jpg',
#   'https://i.imgur.com/Y33geAQ.jpg',
#   'https://i.imgur.com/YoCowxQ.jpg',
#   'https://i.imgur.com/bKRWIyY.jpg',
#   'https://i.imgur.com/frVo9MN.jpg',
#   'https://i.imgur.com/kKtmYf7.jpg',
#   'https://i.imgur.com/GTiGt4z.jpg',
#   'https://i.imgur.com/XeIi24Z.jpg',
#   'https://i.imgur.com/XRuvliq.jpg',
#   'https://i.imgur.com/OBRzNhO.jpg',
#   'https://i.imgur.com/8YWTF8T.jpg',
#   'https://i.imgur.com/dSIkyEh.jpg',
#   'https://i.imgur.com/m7NkQGF.jpg',
#   '',
#   '3號',
#   'https://i.imgur.com/H5EQnEk.jpg',
#   'https://i.imgur.com/Swm8NXM.jpg',
#   'https://i.imgur.com/lsaDoSW.jpg',
#   'https://i.imgur.com/E8Ychwd.jpg',
#   'https://i.imgur.com/TbC2Lmj.jpg',
#   'https://i.imgur.com/gJVg6M9.jpg',
#   'https://i.imgur.com/hhnAxh5.jpg',
#   'https://i.imgur.com/DHiGcFe.jpg',
#   'https://i.imgur.com/4JEov57.jpg',
#   'https://i.imgur.com/Vyy54YZ.jpg',
#   'https://i.imgur.com/URz6XEG.jpg',
#   'https://i.imgur.com/YHhAc3P.jpg',
#   'https://i.imgur.com/pmRmZnZ.jpg',
#   'https://i.imgur.com/MG7PYY0.jpg',
#   '',
#   '4號',
#   'https://i.imgur.com/PoFahok.jpg',
#   'https://i.imgur.com/B5UiR9G.jpg',
#   'https://i.imgur.com/2k3bncf.jpg',
#   'https://i.imgur.com/QHGVNMn.jpg',
#   '',
#   '',
#   '--',
#   '純分享給網友欣賞，網友留言時也請尊重女性',
#   '',
#   '若本人不願上表特版請來信告知',
#   '',
#   '無PTT帳號者，亦可向表特板官方粉絲團私訊反應',
#   'http://www.facebook.com/PTTBeauty',
#   '',
#   '--'],
#  'datetime': 'Wed May 30 23:28:43 2018',
#  'ip': '220.134.113.59',
#  'pushes': [{'push_content': '…',
#    'push_ipdatetime': '05/30 23:29',
#    'push_tag': '噓',
#    'push_userid': 'ja88281'},
#   {'push_content': '這次姆士還不錯啦',
#    'push_ipdatetime': '05/30 23:35',
#    'push_tag': '推',
#    'push_userid': 'peter0612'},
#   {'push_content': '2號',
#    'push_ipdatetime': '05/30 23:35',
#    'push_tag': '推',
#    'push_userid': 'KKKKJAY'},
#   {'push_content': '1號',
#    'push_ipdatetime': '05/30 23:38',
#    'push_tag': '推',
#    'push_userid': 'gen001'},
#   {'push_content': '1、2還OK啦',
#    'push_ipdatetime': '05/30 23:40',
#    'push_tag': '推',
#    'push_userid': 'lovegogi'},
#   {'push_content': '1111111',
#    'push_ipdatetime': '05/30 23:42',
#    'push_tag': '推',
#    'push_userid': 'fbi0072004'},
#   {'push_content': '2',
#    'push_ipdatetime': '05/30 23:46',
#    'push_tag': '推',
#    'push_userid': 'yingrenhao'},
#   {'push_content': '我全部都要',
#    'push_ipdatetime': '05/30 23:49',
#    'push_tag': '推',
#    'push_userid': 'chubby31190'},
#   {'push_content': '1、2可 都竹女了應該不會還選不到好的',
#    'push_ipdatetime': '05/30 23:50',
#    'push_tag': '推',
#    'push_userid': 'qzwxecrv55'},
#   {'push_content': '泥把我直屬學妹的臉馬掉了=3=',
#    'push_ipdatetime': '05/31 00:01',
#    'push_tag': '推',
#    'push_userid': 'irisowo'},
#   {'push_content': '喜歡2號',
#    'push_ipdatetime': '05/31 00:02',
#    'push_tag': '推',
#    'push_userid': 'pk90027'},
#   {'push_content': '竹女出品品質保證',
#    'push_ipdatetime': '05/31 00:03',
#    'push_tag': '推',
#    'push_userid': 'r06543'},
#   {'push_content': '新竹的學妹 給推',
#    'push_ipdatetime': '05/31 00:08',
#    'push_tag': '推',
#    'push_userid': 'j9131993'},
#   {'push_content': '門勒',
#    'push_ipdatetime': '05/31 00:16',
#    'push_tag': '推',
#    'push_userid': 'Kevintsaitsa'},
#   {'push_content': '1,2求門',
#    'push_ipdatetime': '05/31 00:18',
#    'push_tag': '推',
#    'push_userid': 'mgochen'},
#   {'push_content': '蠻優的',
#    'push_ipdatetime': '05/31 00:22',
#    'push_tag': '推',
#    'push_userid': 'morgen'},
#   {'push_content': '為什麼1號讓我有看到Momo的錯覺',
#    'push_ipdatetime': '05/31 00:22',
#    'push_tag': '推',
#    'push_userid': 'Linkzibata12'},
#   {'push_content': '讚讚',
#    'push_ipdatetime': '05/31 00:24',
#    'push_tag': '推',
#    'push_userid': 'DutchLord000'},
#   {'push_content': '現在女高中生標準粧容',
#    'push_ipdatetime': '05/31 00:24',
#    'push_tag': '推',
#    'push_userid': 'franz10123'},
#   {'push_content': '1號 房鈺玲 2號 許冠寧',
#    'push_ipdatetime': '05/31 00:39',
#    'push_tag': '推',
#    'push_userid': 'nctuhandsome'},
#   {'push_content': '11111111111111111111',
#    'push_ipdatetime': '05/31 00:44',
#    'push_tag': '推',
#    'push_userid': 'Uncontinue'},
#   {'push_content': '唱歌真的好聽',
#    'push_ipdatetime': '05/31 00:47',
#    'push_tag': '推',
#    'push_userid': 'tzuchun42'},
#   {'push_content': '2號是我喜歡的類型',
#    'push_ipdatetime': '05/31 00:58',
#    'push_tag': '推',
#    'push_userid': 'howard24'},
#   {'push_content': '覺得可以',
#    'push_ipdatetime': '05/31 01:01',
#    'push_tag': '推',
#    'push_userid': 'qqoo40282'},
#   {'push_content': '二號臥蠶好可愛',
#    'push_ipdatetime': '05/31 01:04',
#    'push_tag': '推',
#    'push_userid': 'deathslipkno'},
#   {'push_content': '☺',
#    'push_ipdatetime': '05/31 01:06',
#    'push_tag': '推',
#    'push_userid': 'RG5678'},
#   {'push_content': '2',
#    'push_ipdatetime': '05/31 01:16',
#    'push_tag': '推',
#    'push_userid': 'n61208'},
#   {'push_content': '全都無法',
#    'push_ipdatetime': '05/31 01:32',
#    'push_tag': '噓',
#    'push_userid': 'sailinbo'},
#   {'push_content': '本來就還好，妝大扣分',
#    'push_ipdatetime': '05/31 01:41',
#    'push_tag': '→',
#    'push_userid': 'babyMclaren'},
#   {'push_content': '2號可以',
#    'push_ipdatetime': '05/31 01:42',
#    'push_tag': '推',
#    'push_userid': 'joe199277'},
#   {'push_content': '11111112222222',
#    'push_ipdatetime': '05/31 01:58',
#    'push_tag': '推',
#    'push_userid': 'kai6366'},
#   {'push_content': '喜歡1號的歌聲，欣賞2號的才華',
#    'push_ipdatetime': '05/31 02:06',
#    'push_tag': '推',
#    'push_userid': 'k9845'},
#   {'push_content': '推',
#    'push_ipdatetime': '05/31 03:17',
#    'push_tag': '推',
#    'push_userid': 'liu3078505'},
#   {'push_content': '全都不行',
#    'push_ipdatetime': '05/31 03:55',
#    'push_tag': '噓',
#    'push_userid': 'mirac1e'},
#   {'push_content': '推',
#    'push_ipdatetime': '05/31 06:04',
#    'push_tag': '推',
#    'push_userid': 'man138888'},
#   {'push_content': '3號有一種獨特的氣質',
#    'push_ipdatetime': '05/31 06:37',
#    'push_tag': '推',
#    'push_userid': 'conq'},
#   {'push_content': '1,2',
#    'push_ipdatetime': '05/31 06:47',
#    'push_tag': '推',
#    'push_userid': 'schgun820'},
#   {'push_content': '幾張像高嘉瑜',
#    'push_ipdatetime': '05/31 07:04',
#    'push_tag': '推',
#    'push_userid': 'beautyest'},
#   {'push_content': '樓下支援幣卡索',
#    'push_ipdatetime': '05/31 07:56',
#    'push_tag': '推',
#    'push_userid': 'abellea85209'},
#   {'push_content': '.....',
#    'push_ipdatetime': '05/31 07:58',
#    'push_tag': '噓',
#    'push_userid': 'neo82430'},
#   {'push_content': '2號很正耶',
#    'push_ipdatetime': '05/31 08:25',
#    'push_tag': '推',
#    'push_userid': 'PoyuCHENG'},
#   {'push_content': '姆斯你這樣母湯，素質都不錯，可是為化妝而化妝',
#    'push_ipdatetime': '05/31 08:28',
#    'push_tag': '推',
#    'push_userid': 'niji5143'},
#   {'push_content': '好聽好聽',
#    'push_ipdatetime': '05/31 08:32',
#    'push_tag': '推',
#    'push_userid': 'pukai'},
#   {'push_content': '這次很可以',
#    'push_ipdatetime': '05/31 08:33',
#    'push_tag': '推',
#    'push_userid': 'belucky'},
#   {'push_content': '2號不適合古裝',
#    'push_ipdatetime': '05/31 08:51',
#    'push_tag': '→',
#    'push_userid': 'pase139'},
#   {'push_content': '竹女出妹子',
#    'push_ipdatetime': '05/31 09:06',
#    'push_tag': '推',
#    'push_userid': 'danny0108'},
#   {'push_content': '1',
#    'push_ipdatetime': '05/31 09:17',
#    'push_tag': '推',
#    'push_userid': 'yluok'},
#   {'push_content': 'U質',
#    'push_ipdatetime': '05/31 09:20',
#    'push_tag': '推',
#    'push_userid': 'ColdM'},
#   {'push_content': '2號',
#    'push_ipdatetime': '05/31 10:28',
#    'push_tag': '推',
#    'push_userid': 'liang94313'},
#   {'push_content': '推友校<3 人家化妝到底乾妳什麼事啦',
#    'push_ipdatetime': '05/31 11:01',
#    'push_tag': '推',
#    'push_userid': 'rinamedia'},
#   {'push_content': '我覺得可以',
#    'push_ipdatetime': '05/31 11:03',
#    'push_tag': '推',
#    'push_userid': 'socialhero'},
#   {'push_content': '這篇我跪著看 母獅可以收我為徒嗎嗚嗚  我也很喜歡1',
#    'push_ipdatetime': '05/31 11:46',
#    'push_tag': '推',
#    'push_userid': 'unavoidable'},
#   {'push_content': '號XD',
#    'push_ipdatetime': '05/31 11:46',
#    'push_tag': '→',
#    'push_userid': 'unavoidable'},
#   {'push_content': '2 號 跪求開門',
#    'push_ipdatetime': '05/31 12:08',
#    'push_tag': '推',
#    'push_userid': 'vanillamint'},
#   {'push_content': '堅持才有價值',
#    'push_ipdatetime': '05/31 12:42',
#    'push_tag': '推',
#    'push_userid': 'Bilison'},
#   {'push_content': '我想說的意思是，明明還有本錢，沒化妝可能也很好看甚至',
#    'push_ipdatetime': '05/31 13:29',
#    'push_tag': '→',
#    'push_userid': 'niji5143'},
#   {'push_content': '更好看，但化了一個不明所以的妝',
#    'push_ipdatetime': '05/31 13:29',
#    'push_tag': '→',
#    'push_userid': 'niji5143'},
#   {'push_content': '短髮那位呢',
#    'push_ipdatetime': '05/31 13:43',
#    'push_tag': '噓',
#    'push_userid': 'fallensam'}],
#  'url': 'https://www.ptt.cc/bbs/Beauty/M.1527694127.A.D6E.html'}
